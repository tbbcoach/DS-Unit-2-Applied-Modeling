# %% [markdown]
# <a href="https://colab.research.google.com/github/tbbcoach/DS-Unit-2-Applied-Modeling/blob/master/tim_avocado_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# from google.colab import files
# upload =files.upload()

# %%
df_avocado = pd.read_csv('Augmented_avocado.csv')
df_avocado = df_avocado.drop(columns='Unnamed: 0')
df_avocado.head()
# Out:
#          Date  AveragePrice  ...         year        region
# 0   4/23/2017      1.324522  ...  2016.012571       Roanoke
# 1   3/29/2015      1.297376  ...  2015.015347  SanFrancisco
# 2   2/18/2018      1.469304  ...  2016.010241    Louisville
# 3  11/15/2015      1.681869  ...  2017.012494        Albany
# 4   6/21/2015      1.334113  ...  2015.007340  SanFrancisco
#
# [5 rows x 13 columns]

# %%
df_avocado['Date'] = pd.to_datetime(df_avocado['Date'])

# %%
df_avocado.set_index('Date')
df_avocado.head()
# Out:
#         Date  AveragePrice  ...         year        region
# 0 2017-04-23      1.324522  ...  2016.012571       Roanoke
# 1 2015-03-29      1.297376  ...  2015.015347  SanFrancisco
# 2 2018-02-18      1.469304  ...  2016.010241    Louisville
# 3 2015-11-15      1.681869  ...  2017.012494        Albany
# 4 2015-06-21      1.334113  ...  2015.007340  SanFrancisco
#
# [5 rows x 13 columns]

# %%
df_avocado = df_avocado.sort_values(['Date'], ascending=True)
df_avocado.head(15)
# Out:
#              Date  AveragePrice  ...         year               region
# 59834  2015-01-04      1.067238  ...  2015.996867               Denver
# 59228  2015-01-04      1.182851  ...  2017.021296      RichmondNorfolk
# 519488 2015-01-04      1.010103  ...  2016.015915          GrandRapids
# 792274 2015-01-04      2.037675  ...  2014.998154   NorthernNewEngland
# 994382 2015-01-04      2.631752  ...  2016.011704     WestTexNewMexico
# 190394 2015-01-04      0.925108  ...  2015.999748          GrandRapids
# 643923 2015-01-04      1.111902  ...  2014.983933             Columbus
# 43963  2015-01-04      0.951231  ...  2014.995032              NewYork
# 994390 2015-01-04      1.884394  ...  2017.009626  HartfordSpringfield
# 519541 2015-01-04      0.802034  ...  2015.994644        PhoenixTucson
# 332849 2015-01-04      1.617182  ...  2015.996337              Orlando
# 74107  2015-01-04      0.945541  ...  2016.006399     WestTexNewMexico
# ...

# %%
#rename product SKU to actual size wording
df_avocado = df_avocado.rename(columns={'4046' : 'Small_medium', '4225' : 'Large', '4770' : 'Extra_large'})
df_avocado.head()
# Out:
#              Date  AveragePrice  ...         year              region
# 59834  2015-01-04      1.067238  ...  2015.996867              Denver
# 59228  2015-01-04      1.182851  ...  2017.021296     RichmondNorfolk
# 519488 2015-01-04      1.010103  ...  2016.015915         GrandRapids
# 792274 2015-01-04      2.037675  ...  2014.998154  NorthernNewEngland
# 994382 2015-01-04      2.631752  ...  2016.011704    WestTexNewMexico
#
# [5 rows x 13 columns]

# %%
df_avocado.describe()
# Out:
#          AveragePrice  Total Volume  ...     XLarge Bags            year
# count  1000000.000000  1.000000e+06  ...  1000000.000000  1000000.000000
# mean         1.327046  7.642013e+05  ...     2235.053628     2015.832870
# std          0.354661  2.707319e+06  ...     9068.713079        0.835986
# min          0.404900 -1.229313e+05  ...    -1190.679383     2014.951891
# 25%          1.043487  3.783969e+04  ...      -65.962414     2015.009572
# 50%          1.304480  1.109835e+05  ...       18.261568     2015.997080
# 75%          1.594414  6.384961e+05  ...      134.315549     2016.010458
# max          3.099375  4.865125e+07  ...   137466.484400     2018.153724
#
# [8 rows x 10 columns]

# %%
df_avocado['region'].value_counts(normalize=True)
# Out:
# Indianapolis           0.026272
# California             0.026030
# GrandRapids            0.025987
# Detroit                0.024831
# SouthCarolina          0.024747
# Southeast              0.023817
# Seattle                0.023576
# Northeast              0.022760
# HarrisburgScranton     0.021887
# NewOrleansMobile       0.021635
# Pittsburgh             0.021348
# Nashville              0.020746
# Tampa                  0.020592
# PhoenixTucson          0.019963
# Portland               0.019680
# CincinnatiDayton       0.019419
# Atlanta                0.019413
# SanFrancisco           0.019297
# Jacksonville           0.019225
# SanDiego               0.018910
# LosAngeles             0.018891
# Chicago                0.018674
# Denver                 0.018419
# Spokane                0.018409
# DallasFtWorth          0.018185
# GreatLakes             0.018139
# Louisville             0.017776
# BuffaloRochester       0.017690
# MiamiFtLauderdale      0.017604
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(df_avocado['Total Volume'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_avocado['log_tot_volume'] = np.log(df_avocado['Total Volume'])

sns.distplot(df_avocado['log_tot_volume'])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cutoff = 1.33
mask = df_avocado.AveragePrice <= cutoff
df_avocado_cheap = df_avocado.loc[mask]
df_avocado_expensive = df_avocado.loc[~mask]
df_avocado_cheap.head()
# Out:
#              Date  AveragePrice  ...           region  log_tot_volume
# 59834  2015-01-04      1.067238  ...           Denver       13.675666
# 59228  2015-01-04      1.182851  ...  RichmondNorfolk       12.734392
# 519488 2015-01-04      1.010103  ...      GrandRapids       13.819416
# 190394 2015-01-04      0.925108  ...      GrandRapids       11.621370
# 643923 2015-01-04      1.111902  ...         Columbus       10.272477
#
# [5 rows x 14 columns]

# %%
df_avocado['cheap'] = df_avocado.AveragePrice <= cutoff
df_avocado.head()
# Out:
#              Date  AveragePrice  ...  log_tot_volume  cheap
# 59834  2015-01-04      1.067238  ...       13.675666   True
# 59228  2015-01-04      1.182851  ...       12.734392   True
# 519488 2015-01-04      1.010103  ...       13.819416   True
# 792274 2015-01-04      2.037675  ...       10.754536  False
# 994382 2015-01-04      2.631752  ...             NaN  False
#
# [5 rows x 15 columns]
